# %% [markdown]
# # SETUP

# %% [markdown]
# ## is GPU on?

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %% [markdown]
# ## boilerplate

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping
from numpy import arange

MODEL_NAME = 'mobilenet'
IMG_SIZE = (224, 224)
INPUT_SHAPE=(224, 224, 3)
CLASSES = 2
FT_BLOCK = 10 # FROM feature extractor TO fine tuning scratch
BATCH_SIZE = 64 # these data points will be passed as a batch at one time to the network
PR_RATIO = list(arange(1,10,1))
TRIAL = list(arange(0,10,1))
MODEL_DIR = '../../models/PR'

# %% [markdown]
# ## UDC/Fs

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras import layers
from math import floor
from timeit import default_timer as timer
from json import dump
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow import data
from keras.engine import training

def model_constructor(FT_BLOCK):
    base_model = MobileNet(
        weights='imagenet', 
        include_top=False,
        input_shape=INPUT_SHAPE)
    
    # construct the top layer containing 
    x = base_model.output
    x = layers.GlobalAveragePooling2D(keepdims=True)(x)
    x = layers.Dropout(1e-3, name='dropout')(x)
    x = layers.Conv2D(CLASSES, (1, 1), padding='same', name='conv_preds')(x)
    x = layers.Reshape((CLASSES,), name='reshape_2')(x)
    x = layers.Activation(activation='sigmoid', name='predictions')(x)
    
    # model is ready to be trained
    alpha, rows = 1.0, 224
    model = training.Model(inputs=base_model.input, outputs=x, name='mobilenet_%0.2f_%s' % (alpha, rows))

    # freeze the layers before the `FROZEN_END` layer 
    total_layers = len(base_model.layers)
    ft_layers = floor(total_layers / 10)
    FROZEN_END = total_layers - ft_layers * FT_BLOCK

    base_model.trainable = True
    for layer in base_model.layers[:FROZEN_END]: 
        layer.trainable = False
    
    return model

class TimeCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

def time_converter(sec):
    hours, rem = divmod(sec, 3600)
    minutes, seconds = divmod(rem, 60)
    print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))

def save_history(history, tag):
    file_path = f'{HISTORY_DIR}/{tag}.json'
    with open(file_path, 'w') as f:
        dump(history.history, f)
        
def data_preparation(BATCH_SIZE):
    train_dir = '../../data/binaryclass_clean/train/'
    test_dir = '../../data/binaryclass_clean/test/'

    train_ds = image_dataset_from_directory(
        directory=train_dir,
        label_mode='categorical',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        seed=0,
        validation_split=0.1,
        subset='training')

    val_ds = image_dataset_from_directory(
        directory=train_dir,
        label_mode='categorical',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        seed=0,
        validation_split=0.1,
        subset='validation')

    test_ds = image_dataset_from_directory(
        directory=test_dir,
        label_mode='categorical',
        batch_size=1,
        image_size=IMG_SIZE)

    AUTOTUNE = data.AUTOTUNE
    train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
    val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
    
    return train_ds, val_ds, test_ds

import tempfile
from os.path import getsize

def get_gzipped_model_size(file):
  # Returns size of gzipped model, in Mbytes.
  import os
  import zipfile

  zipped_file = f'{MODEL_DIR}/{tag}.zip'
  with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write(file)
    zipped_size = getsize(zipped_file) / float(2**20)
#     remove(zipped_file)

  return zipped_size

# %%
train_ds, val_ds, test_ds = data_preparation(BATCH_SIZE)
# Out:
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# # GRID SEARCH

# %%
import tensorflow_model_optimization as tfmot
from tensorflow.keras.models import save_model

for i in TRIAL:
    print(" - - - - - TRIAL:", i, " - - - - - ")
    loss, accuracy, model_size = [None]*len(PR_RATIO), [None]*len(PR_RATIO), [None]*len(PR_RATIO)

    for pr in PR_RATIO:
        tag = f'{MODEL_NAME}_BS{BATCH_SIZE}_FT{FT_BLOCK*10}_PR{pr*10}_{i}'
        print(tag)

        logdir = f'../../logs/PR/{tag}.json'
        callbacks = [
            tfmot.sparsity.keras.UpdatePruningStep(),
            tfmot.sparsity.keras.PruningSummaries(log_dir=logdir),
        ]
        pruning_params = {
            'pruning_schedule': tfmot.sparsity.keras.ConstantSparsity(
                target_sparsity=pr/10, begin_step=0, end_step=-1, frequency=1)}

        model = model_constructor(FT_BLOCK)
        prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
        model_for_pruning = prune_low_magnitude(model, **pruning_params)
        # model_for_pruning.summary()

        model_for_pruning.compile(loss='binary_crossentropy', metrics='accuracy', optimizer = 'adam')
        history = model_for_pruning.fit(train_ds, epochs=100, verbose=0, validation_data=val_ds, callbacks=callbacks)

        loss[pr-1], accuracy[pr-1] = model_for_pruning.evaluate(test_ds)

    # PRINT THE RESULT
    print(f' * * * * * {tag[:-2]}_10-90_LOSS * * * * * ')
    for item in loss:
        print(item)
    print(f' * * * * * {tag[:-2]}_10-90_ACCURACY * * * * * ')
    for item in accuracy:
        print(item)
    print(f' * * * * * {tag[:-2]}_10-90_MODEL SIZE * * * * * ')
    for item in model_size:
        print(item)
# Out:
#  - - - - - TRIAL: 0  - - - - -
# mobilenet_BS64_FT100_PR10_0
# /usr/local/lib/python3.6/dist-packages/keras/engine/base_layer.py:2223: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1731s vs `on_train_batch_end` time: 0.2063s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5237 - accuracy: 0.9010
# mobilenet_BS64_FT100_PR20_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1569s vs `on_train_batch_end` time: 0.3486s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.8402 - accuracy: 0.8900
# mobilenet_BS64_FT100_PR30_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1626s vs `on_train_batch_end` time: 0.3378s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.6329 - accuracy: 0.9140
# mobilenet_BS64_FT100_PR40_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1568s vs `on_train_batch_end` time: 0.4060s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7873 - accuracy: 0.8990
# mobilenet_BS64_FT100_PR50_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1538s vs `on_train_batch_end` time: 0.3401s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.9492 - accuracy: 0.8800
# mobilenet_BS64_FT100_PR60_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1514s vs `on_train_batch_end` time: 0.3375s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7319 - accuracy: 0.8780
# mobilenet_BS64_FT100_PR70_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1537s vs `on_train_batch_end` time: 0.3423s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.7485 - accuracy: 0.8790
# mobilenet_BS64_FT100_PR80_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1551s vs `on_train_batch_end` time: 0.3344s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 1.1767 - accuracy: 0.8400
# mobilenet_BS64_FT100_PR90_0
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1599s vs `on_train_batch_end` time: 0.3347s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 2.5246 - accuracy: 0.6490
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.5236846208572388
# 0.8401680588722229
# 0.6328557729721069
# 0.7872768044471741
# 0.9491704106330872
# 0.7318993806838989
# 0.7485010027885437
# 1.1766610145568848
# 2.524632453918457
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.9010000228881836
# 0.8899999856948853
# 0.9139999747276306
# 0.8989999890327454
# 0.8799999952316284
# 0.878000020980835
# 0.8790000081062317
# 0.8399999737739563
# 0.6489999890327454
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 1  - - - - -
# mobilenet_BS64_FT100_PR10_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1615s vs `on_train_batch_end` time: 0.3355s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.8502 - accuracy: 0.9010
# mobilenet_BS64_FT100_PR20_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1494s vs `on_train_batch_end` time: 0.3329s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.7828 - accuracy: 0.9080
# mobilenet_BS64_FT100_PR30_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1596s vs `on_train_batch_end` time: 0.3417s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8646 - accuracy: 0.8700
# mobilenet_BS64_FT100_PR40_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1522s vs `on_train_batch_end` time: 0.3485s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6728 - accuracy: 0.8970
# mobilenet_BS64_FT100_PR50_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1542s vs `on_train_batch_end` time: 0.3413s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.9732 - accuracy: 0.8760
# mobilenet_BS64_FT100_PR60_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1522s vs `on_train_batch_end` time: 0.3494s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8892 - accuracy: 0.8810
# mobilenet_BS64_FT100_PR70_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1523s vs `on_train_batch_end` time: 0.3457s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 1.2000 - accuracy: 0.8630
# mobilenet_BS64_FT100_PR80_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1570s vs `on_train_batch_end` time: 0.3366s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.7128 - accuracy: 0.8800
# mobilenet_BS64_FT100_PR90_1
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1555s vs `on_train_batch_end` time: 0.3366s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 2.2495 - accuracy: 0.5100
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.8502449989318848
# 0.7828361988067627
# 0.864642322063446
# 0.6728456616401672
# 0.9732459187507629
# 0.8891662359237671
# 1.200034260749817
# 0.7127660512924194
# 2.2494606971740723
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.9010000228881836
# 0.9079999923706055
# 0.8700000047683716
# 0.8970000147819519
# 0.8759999871253967
# 0.8809999823570251
# 0.8629999756813049
# 0.8799999952316284
# 0.5099999904632568
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 2  - - - - -
# mobilenet_BS64_FT100_PR10_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1575s vs `on_train_batch_end` time: 0.3370s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 1.1977 - accuracy: 0.8960
# mobilenet_BS64_FT100_PR20_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1564s vs `on_train_batch_end` time: 0.3586s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7064 - accuracy: 0.9100
# mobilenet_BS64_FT100_PR30_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1541s vs `on_train_batch_end` time: 0.3450s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.9337 - accuracy: 0.8930
# mobilenet_BS64_FT100_PR40_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1547s vs `on_train_batch_end` time: 0.3371s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.8244 - accuracy: 0.9060
# mobilenet_BS64_FT100_PR50_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1578s vs `on_train_batch_end` time: 0.3424s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7462 - accuracy: 0.8900
# mobilenet_BS64_FT100_PR60_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1610s vs `on_train_batch_end` time: 0.3346s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8912 - accuracy: 0.8860
# mobilenet_BS64_FT100_PR70_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1528s vs `on_train_batch_end` time: 0.3401s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.8736 - accuracy: 0.8670
# mobilenet_BS64_FT100_PR80_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1519s vs `on_train_batch_end` time: 0.3421s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.8383 - accuracy: 0.8700
# mobilenet_BS64_FT100_PR90_2
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1599s vs `on_train_batch_end` time: 0.3421s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 1.7538 - accuracy: 0.6350
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 1.1977275609970093
# 0.7064472436904907
# 0.9336770176887512
# 0.8243740797042847
# 0.7461749911308289
# 0.8912068605422974
# 0.8736208081245422
# 0.838321328163147
# 1.7537615299224854
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.8960000276565552
# 0.9100000262260437
# 0.8930000066757202
# 0.906000018119812
# 0.8899999856948853
# 0.8859999775886536
# 0.8669999837875366
# 0.8700000047683716
# 0.6349999904632568
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 3  - - - - -
# mobilenet_BS64_FT100_PR10_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1526s vs `on_train_batch_end` time: 0.3343s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8295 - accuracy: 0.9070
# mobilenet_BS64_FT100_PR20_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1568s vs `on_train_batch_end` time: 0.3615s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7998 - accuracy: 0.8990
# mobilenet_BS64_FT100_PR30_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1584s vs `on_train_batch_end` time: 0.3473s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.6737 - accuracy: 0.9210
# mobilenet_BS64_FT100_PR40_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1570s vs `on_train_batch_end` time: 0.3319s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.8157 - accuracy: 0.8970
# mobilenet_BS64_FT100_PR50_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1561s vs `on_train_batch_end` time: 0.3390s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.8424 - accuracy: 0.8670
# mobilenet_BS64_FT100_PR60_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1519s vs `on_train_batch_end` time: 0.3328s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.7043 - accuracy: 0.8840
# mobilenet_BS64_FT100_PR70_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1577s vs `on_train_batch_end` time: 0.3458s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 1.6761 - accuracy: 0.8080
# mobilenet_BS64_FT100_PR80_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1595s vs `on_train_batch_end` time: 0.3414s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 1.6169 - accuracy: 0.7570
# mobilenet_BS64_FT100_PR90_3
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1541s vs `on_train_batch_end` time: 0.3382s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 1.0466 - accuracy: 0.6910
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.8295485377311707
# 0.7998401522636414
# 0.6737399697303772
# 0.8157347440719604
# 0.8423795700073242
# 0.7043353915214539
# 1.676077127456665
# 1.6168715953826904
# 1.0465710163116455
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.9070000052452087
# 0.8989999890327454
# 0.9210000038146973
# 0.8970000147819519
# 0.8669999837875366
# 0.8840000033378601
# 0.8080000281333923
# 0.7570000290870667
# 0.6909999847412109
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 4  - - - - -
# mobilenet_BS64_FT100_PR10_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1692s vs `on_train_batch_end` time: 0.3352s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7579 - accuracy: 0.9020
# mobilenet_BS64_FT100_PR20_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1710s vs `on_train_batch_end` time: 0.3614s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.8351 - accuracy: 0.8860
# mobilenet_BS64_FT100_PR30_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1578s vs `on_train_batch_end` time: 0.3492s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7703 - accuracy: 0.8870
# mobilenet_BS64_FT100_PR40_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1510s vs `on_train_batch_end` time: 0.3330s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8118 - accuracy: 0.9020
# mobilenet_BS64_FT100_PR50_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1680s vs `on_train_batch_end` time: 0.3396s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.6808 - accuracy: 0.9050
# mobilenet_BS64_FT100_PR60_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1520s vs `on_train_batch_end` time: 0.3315s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 1.0473 - accuracy: 0.8620
# mobilenet_BS64_FT100_PR70_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1649s vs `on_train_batch_end` time: 0.3413s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 1.1507 - accuracy: 0.8720
# mobilenet_BS64_FT100_PR80_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1589s vs `on_train_batch_end` time: 0.3479s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.9335 - accuracy: 0.8600
# mobilenet_BS64_FT100_PR90_4
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1514s vs `on_train_batch_end` time: 0.3447s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 3.0986 - accuracy: 0.6050
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.7578768730163574
# 0.8350611925125122
# 0.7702692747116089
# 0.811821460723877
# 0.6807699203491211
# 1.0472522974014282
# 1.1507318019866943
# 0.9335088729858398
# 3.098572254180908
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.9020000100135803
# 0.8859999775886536
# 0.8870000243186951
# 0.9020000100135803
# 0.9049999713897705
# 0.8619999885559082
# 0.871999979019165
# 0.8600000143051147
# 0.6050000190734863
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 5  - - - - -
# mobilenet_BS64_FT100_PR10_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1563s vs `on_train_batch_end` time: 0.3357s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8613 - accuracy: 0.9080
# mobilenet_BS64_FT100_PR20_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1604s vs `on_train_batch_end` time: 0.3779s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6290 - accuracy: 0.8970
# mobilenet_BS64_FT100_PR30_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1582s vs `on_train_batch_end` time: 0.3444s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.7005 - accuracy: 0.8960
# mobilenet_BS64_FT100_PR40_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1513s vs `on_train_batch_end` time: 0.3369s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8123 - accuracy: 0.8980
# mobilenet_BS64_FT100_PR50_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1515s vs `on_train_batch_end` time: 0.3408s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8507 - accuracy: 0.8870
# mobilenet_BS64_FT100_PR60_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1560s vs `on_train_batch_end` time: 0.3364s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8853 - accuracy: 0.8790
# mobilenet_BS64_FT100_PR70_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1564s vs `on_train_batch_end` time: 0.3452s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7628 - accuracy: 0.8220
# mobilenet_BS64_FT100_PR80_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1549s vs `on_train_batch_end` time: 0.3521s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 1.5436 - accuracy: 0.7020
# mobilenet_BS64_FT100_PR90_5
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1556s vs `on_train_batch_end` time: 0.3484s). Check your callbacks.
# 1000/1000 [==============================] - 7s 6ms/step - loss: 1.6654 - accuracy: 0.5280
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.8613428473472595
# 0.6289704442024231
# 0.7004785537719727
# 0.8122661113739014
# 0.8507327437400818
# 0.8853346705436707
# 0.7627734541893005
# 1.5435532331466675
# 1.665426254272461
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.9079999923706055
# 0.8970000147819519
# 0.8960000276565552
# 0.8980000019073486
# 0.8870000243186951
# 0.8790000081062317
# 0.8220000267028809
# 0.7020000219345093
# 0.527999997138977
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 6  - - - - -
# mobilenet_BS64_FT100_PR10_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1588s vs `on_train_batch_end` time: 0.3420s). Check your callbacks.
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.8614 - accuracy: 0.9000
# mobilenet_BS64_FT100_PR20_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1565s vs `on_train_batch_end` time: 0.3763s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.7540 - accuracy: 0.8840
# mobilenet_BS64_FT100_PR30_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1628s vs `on_train_batch_end` time: 0.3515s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.7875 - accuracy: 0.8920
# mobilenet_BS64_FT100_PR40_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1628s vs `on_train_batch_end` time: 0.3411s). Check your callbacks.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.8659 - accuracy: 0.8780
# mobilenet_BS64_FT100_PR50_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1507s vs `on_train_batch_end` time: 0.3397s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 1.0968 - accuracy: 0.8820
# mobilenet_BS64_FT100_PR60_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2269s vs `on_train_batch_end` time: 0.3840s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8916 - accuracy: 0.8850
# mobilenet_BS64_FT100_PR70_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1959s vs `on_train_batch_end` time: 0.4154s). Check your callbacks.
# 1000/1000 [==============================] - 10s 9ms/step - loss: 0.8194 - accuracy: 0.8810
# mobilenet_BS64_FT100_PR80_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2086s vs `on_train_batch_end` time: 0.4016s). Check your callbacks.
# 1000/1000 [==============================] - 11s 11ms/step - loss: 0.8608 - accuracy: 0.8820
# mobilenet_BS64_FT100_PR90_6
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2189s vs `on_train_batch_end` time: 0.3962s). Check your callbacks.
# 1000/1000 [==============================] - 10s 9ms/step - loss: 1.7386 - accuracy: 0.7310
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.8614060282707214
# 0.7540078163146973
# 0.7874894142150879
# 0.86589515209198
# 1.0967706441879272
# 0.891552209854126
# 0.8193952441215515
# 0.8608140349388123
# 1.7386186122894287
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.8999999761581421
# 0.8840000033378601
# 0.8920000195503235
# 0.878000020980835
# 0.8820000290870667
# 0.8849999904632568
# 0.8809999823570251
# 0.8820000290870667
# 0.7310000061988831
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 7  - - - - -
# mobilenet_BS64_FT100_PR10_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2160s vs `on_train_batch_end` time: 0.3883s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8885 - accuracy: 0.8860
# mobilenet_BS64_FT100_PR20_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2066s vs `on_train_batch_end` time: 0.4412s). Check your callbacks.
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.7635 - accuracy: 0.8910
# mobilenet_BS64_FT100_PR30_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2215s vs `on_train_batch_end` time: 0.3898s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8302 - accuracy: 0.9090
# mobilenet_BS64_FT100_PR40_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2535s vs `on_train_batch_end` time: 0.4318s). Check your callbacks.
# 1000/1000 [==============================] - 10s 9ms/step - loss: 0.9818 - accuracy: 0.8400
# mobilenet_BS64_FT100_PR50_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2023s vs `on_train_batch_end` time: 0.4002s). Check your callbacks.
# 1000/1000 [==============================] - 11s 11ms/step - loss: 0.6035 - accuracy: 0.8750
# mobilenet_BS64_FT100_PR60_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1996s vs `on_train_batch_end` time: 0.3965s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.9017 - accuracy: 0.8590
# mobilenet_BS64_FT100_PR70_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1787s vs `on_train_batch_end` time: 0.4031s). Check your callbacks.
# 1000/1000 [==============================] - 11s 11ms/step - loss: 0.9000 - accuracy: 0.8450
# mobilenet_BS64_FT100_PR80_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1934s vs `on_train_batch_end` time: 0.4021s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.9198 - accuracy: 0.8950
# mobilenet_BS64_FT100_PR90_7
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2023s vs `on_train_batch_end` time: 0.4020s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8893 - accuracy: 0.7370
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.8884993195533752
# 0.7635126709938049
# 0.8302448987960815
# 0.9818260073661804
# 0.6035231351852417
# 0.9017170667648315
# 0.8999611139297485
# 0.9197598099708557
# 0.8893251419067383
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.8859999775886536
# 0.890999972820282
# 0.9089999794960022
# 0.8399999737739563
# 0.875
# 0.859000027179718
# 0.8450000286102295
# 0.8949999809265137
# 0.7369999885559082
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 8  - - - - -
# mobilenet_BS64_FT100_PR10_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2013s vs `on_train_batch_end` time: 0.4092s). Check your callbacks.
# 1000/1000 [==============================] - 10s 9ms/step - loss: 0.8453 - accuracy: 0.8740
# mobilenet_BS64_FT100_PR20_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2275s vs `on_train_batch_end` time: 0.4612s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.6797 - accuracy: 0.9000
# mobilenet_BS64_FT100_PR30_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1987s vs `on_train_batch_end` time: 0.4044s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.7127 - accuracy: 0.8880
# mobilenet_BS64_FT100_PR40_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1957s vs `on_train_batch_end` time: 0.4002s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.6092 - accuracy: 0.9000
# mobilenet_BS64_FT100_PR50_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1779s vs `on_train_batch_end` time: 0.3733s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.7690 - accuracy: 0.8780
# mobilenet_BS64_FT100_PR60_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2227s vs `on_train_batch_end` time: 0.3641s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8022 - accuracy: 0.8790
# mobilenet_BS64_FT100_PR70_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1750s vs `on_train_batch_end` time: 0.4411s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.9324 - accuracy: 0.8700
# mobilenet_BS64_FT100_PR80_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2113s vs `on_train_batch_end` time: 0.4275s). Check your callbacks.
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.7874 - accuracy: 0.8530
# mobilenet_BS64_FT100_PR90_8
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1809s vs `on_train_batch_end` time: 0.4464s). Check your callbacks.
# 1000/1000 [==============================] - 10s 9ms/step - loss: 5.0393 - accuracy: 0.5190
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 0.8453062176704407
# 0.6797462105751038
# 0.7127484679222107
# 0.6092479228973389
# 0.7690373063087463
# 0.8021501898765564
# 0.9324163198471069
# 0.7874172329902649
# 5.039330959320068
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.8740000128746033
# 0.8999999761581421
# 0.8880000114440918
# 0.8999999761581421
# 0.878000020980835
# 0.8790000081062317
# 0.8700000047683716
# 0.8529999852180481
# 0.5189999938011169
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None
#  - - - - - TRIAL: 9  - - - - -
# mobilenet_BS64_FT100_PR10_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2287s vs `on_train_batch_end` time: 0.3928s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 1.5401 - accuracy: 0.7770
# mobilenet_BS64_FT100_PR20_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2005s vs `on_train_batch_end` time: 0.4570s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8024 - accuracy: 0.9020
# mobilenet_BS64_FT100_PR30_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2481s vs `on_train_batch_end` time: 0.4118s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8183 - accuracy: 0.9110
# mobilenet_BS64_FT100_PR40_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1796s vs `on_train_batch_end` time: 0.3611s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8366 - accuracy: 0.8890
# mobilenet_BS64_FT100_PR50_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2080s vs `on_train_batch_end` time: 0.4170s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.7774 - accuracy: 0.8830
# mobilenet_BS64_FT100_PR60_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2107s vs `on_train_batch_end` time: 0.3862s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.9014 - accuracy: 0.8880
# mobilenet_BS64_FT100_PR70_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2438s vs `on_train_batch_end` time: 0.4434s). Check your callbacks.
# 1000/1000 [==============================] - 11s 11ms/step - loss: 1.2406 - accuracy: 0.8380
# mobilenet_BS64_FT100_PR80_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2153s vs `on_train_batch_end` time: 0.4158s). Check your callbacks.
# 1000/1000 [==============================] - 10s 10ms/step - loss: 0.8545 - accuracy: 0.8460
# mobilenet_BS64_FT100_PR90_9
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1909s vs `on_train_batch_end` time: 0.3886s). Check your callbacks.
# 1000/1000 [==============================] - 9s 9ms/step - loss: 2.6330 - accuracy: 0.5680
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_LOSS * * * * *
# 1.540076732635498
# 0.802391767501831
# 0.8182882070541382
# 0.8365737795829773
# 0.7774209976196289
# 0.9013737440109253
# 1.2405660152435303
# 0.854482114315033
# 2.632983922958374
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_ACCURACY * * * * *
# 0.7770000100135803
# 0.9020000100135803
# 0.9110000133514404
# 0.8889999985694885
# 0.8830000162124634
# 0.8880000114440918
# 0.8379999995231628
# 0.8460000157356262
# 0.5680000185966492
#  * * * * * mobilenet_BS64_FT100_PR90_10-90_MODEL SIZE * * * * *
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# # MODEL WITHOUT PRUNE

# %%
model = model_constructor(FT_BLOCK)
model.compile(loss='binary_crossentropy', metrics='accuracy', optimizer='adam')
model.fit(train_ds, epochs=100, verbose=0, validation_data=val_ds, callbacks=[])
model.evaluate(test_ds)
# Out:
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.7638 - accuracy: 0.8830
# [0.7637704014778137, 0.8830000162124634]

# %%
# Save the model
model_path = f'{MODEL_DIR}/{MODEL_NAME}_BS{BATCH_SIZE}_FT{FT_BLOCK*10}.h5'
model.save(model_path)

# %%
print("Model size in Mb:", getsize(model_path) / float(2**20))
# Out:
# Model size in Mb: 37.2322998046875
