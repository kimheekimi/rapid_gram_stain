# %% [markdown]
# # SETUP

# %% [markdown]
# ## is GPU on?

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %% [markdown]
# ## boilerplate

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping
from numpy import arange

MODEL_NAME = 'inception3'
IMG_SIZE = (299, 299)
INPUT_SHAPE=(299, 299, 3)
CLASSES = 2
TRIAL = list(arange(3,10)) #list(arange(0,3))
FT_BLOCK = list(arange(0,11)) # FROM feature extractor TO fine tuning scratch
BATCH_SIZE = [32, 64, 128, 256] # these data points will be passed as a batch at one time to the network

# %% [markdown]
# ## UDC/Fs

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import layers
from math import floor
from timeit import default_timer as timer
from json import dump
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow import data

def model_constructor(FT_BLOCK):
    base_model = InceptionV3(
        weights='imagenet', 
        include_top=False,
        input_shape=INPUT_SHAPE)
    
    # construct the top layer containing 
    x = base_model.output
    x = layers.GlobalAveragePooling2D(name='avg_pool')(x) # add a global spatial average pooling layer
    x = layers.Dense(CLASSES, activation='sigmoid',  name='predictions')(x) # and add the output layer for binary class

    # model is ready to be trained
    model = Model(inputs=base_model.input, outputs=x)

    # freeze the layers before the `FROZEN_END` layer 
    total_layers = len(base_model.layers)
    ft_layers = floor(total_layers / 10)
    FROZEN_END = total_layers - ft_layers * FT_BLOCK

    base_model.trainable = True
    for layer in base_model.layers[:FROZEN_END]: 
        layer.trainable = False
    
    return model

class TimeCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

def time_converter(sec):
    hours, rem = divmod(sec, 3600)
    minutes, seconds = divmod(rem, 60)
    print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))

def save_history(history, tag):
    file_path = f'{HISTORY_DIR}/{tag}.json'
    with open(file_path, 'w') as f:
        dump(history.history, f)
        
def data_preparation(BATCH_SIZE):
    train_dir = '../../data/binaryclass_clean/train/'
    test_dir = '../../data/binaryclass_clean/test/'

    train_ds = image_dataset_from_directory(
        directory=train_dir,
        label_mode='categorical',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        seed=0,
        validation_split=0.1,
        subset='training')

    val_ds = image_dataset_from_directory(
        directory=train_dir,
        label_mode='categorical',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        seed=0,
        validation_split=0.1,
        subset='validation')

    test_ds = image_dataset_from_directory(
        directory=test_dir,
        label_mode='categorical',
        batch_size=1,
        image_size=IMG_SIZE)

    AUTOTUNE = data.AUTOTUNE
    train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
    val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
    test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)
    
    return train_ds, val_ds, test_ds

# %% [markdown]
# # GRID SEARCH

# %%
for i in TRIAL:
    print(" - - - - - TRIAL:", i, " - - - - - ")
    HISTORY_DIR = f'../../logs/FT/{i}'
    for batch in BATCH_SIZE:
        print("Batch size:", batch)
        train_ds, val_ds, test_ds = data_preparation(batch)
        epochs, loss, accuracy = [None]*len(FT_BLOCK), [None]*len(FT_BLOCK), [None]*len(FT_BLOCK)
        for ft in FT_BLOCK:
            tag = f'{MODEL_NAME}_BS{batch}_FT{ft*10}'
            print(tag)
            model = model_constructor(ft)
            model.compile(loss='binary_crossentropy', metrics='accuracy', optimizer='adam')
            history = model.fit(train_ds, epochs=100, verbose=0, validation_data=val_ds, callbacks=[EarlyStopping(patience=3)])
            save_history(history, tag)
            # time_converter(sum(cb_time.logs))
            epochs[ft] = len(history.history['loss'])
            loss[ft], accuracy[ft] = model.evaluate(test_ds)
        # PRINT THE RESULT
        # print('Count Epoch:', epochs)
        print(f' * * * * * {MODEL_NAME}_BS{batch}_LOSS * * * * * ')
        for item in loss:
            print(item)
        print(f' * * * * * {MODEL_NAME}_BS{batch}_ACCURACY * * * * * ')
        for item in accuracy:
            print(item)
# Out:
#  - - - - - TRIAL: 0  - - - - -
# Batch size: 32
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS32_FT0
# 1000/1000 [==============================] - 17s 16ms/step - loss: 0.9100 - accuracy: 0.6030
# inception3_BS32_FT10
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5750 - accuracy: 0.7240
# inception3_BS32_FT20
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5896 - accuracy: 0.6890
# inception3_BS32_FT30
# 1000/1000 [==============================] - 28s 28ms/step - loss: 0.6314 - accuracy: 0.6660
# inception3_BS32_FT40
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.5857 - accuracy: 0.6850
# inception3_BS32_FT50
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.4174 - accuracy: 0.8380
# inception3_BS32_FT60
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.4306 - accuracy: 0.8460
# inception3_BS32_FT70
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.4913 - accuracy: 0.8160
# inception3_BS32_FT80
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.3069 - accuracy: 0.8750
# inception3_BS32_FT90
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.3295 - accuracy: 0.8910
# inception3_BS32_FT100
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.5052 - accuracy: 0.9200
#  * * * * * inception3_BS32_LOSS * * * * *
# 0.9099833965301514
# 0.5749565958976746
# 0.5895518660545349
# 0.6313874125480652
# 0.5856519937515259
# 0.41738438606262207
# 0.43064382672309875
# 0.4913223683834076
# 0.3068641722202301
# 0.32954421639442444
# 0.5052021145820618
#  * * * * * inception3_BS32_ACCURACY * * * * *
# 0.6029999852180481
# 0.7239999771118164
# 0.6890000104904175
# 0.6660000085830688
# 0.6850000023841858
# 0.8379999995231628
# 0.8460000157356262
# 0.8159999847412109
# 0.875
# 0.890999972820282
# 0.9200000166893005
# Batch size: 64
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS64_FT0
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.8647 - accuracy: 0.6040
# inception3_BS64_FT10
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.6830 - accuracy: 0.6750
# inception3_BS64_FT20
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.5830 - accuracy: 0.7010
# inception3_BS64_FT30
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.5068 - accuracy: 0.7450
# inception3_BS64_FT40
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.5111 - accuracy: 0.7690
# inception3_BS64_FT50
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.4545 - accuracy: 0.7910
# inception3_BS64_FT60
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.4539 - accuracy: 0.8090
# inception3_BS64_FT70
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.4786 - accuracy: 0.8190
# inception3_BS64_FT80
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.4264 - accuracy: 0.8320
# inception3_BS64_FT90
# 1000/1000 [==============================] - 20s 20ms/step - loss: 0.7454 - accuracy: 0.8270
# inception3_BS64_FT100
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.7803 - accuracy: 0.8240
#  * * * * * inception3_BS64_LOSS * * * * *
# 0.8647045493125916
# 0.683018684387207
# 0.5829821825027466
# 0.5068004727363586
# 0.511051595211029
# 0.45453059673309326
# 0.4538963735103607
# 0.4785683751106262
# 0.42643558979034424
# 0.7454316020011902
# 0.7803182601928711
#  * * * * * inception3_BS64_ACCURACY * * * * *
# 0.6039999723434448
# 0.675000011920929
# 0.7009999752044678
# 0.7450000047683716
# 0.7689999938011169
# 0.7910000085830688
# 0.8090000152587891
# 0.8190000057220459
# 0.8320000171661377
# 0.8270000219345093
# 0.8240000009536743
# Batch size: 128
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS128_FT0
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.8708 - accuracy: 0.6180
# inception3_BS128_FT10
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.7928 - accuracy: 0.5740
# inception3_BS128_FT20
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.5910 - accuracy: 0.6860
# inception3_BS128_FT30
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.8232 - accuracy: 0.5790
# inception3_BS128_FT40
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.8447 - accuracy: 0.5420
# inception3_BS128_FT50
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.6416 - accuracy: 0.7100
# inception3_BS128_FT60
# 1000/1000 [==============================] - 34s 33ms/step - loss: 2.4270 - accuracy: 0.6790
# inception3_BS128_FT70
# 1000/1000 [==============================] - 55s 55ms/step - loss: 0.5389 - accuracy: 0.7820
# inception3_BS128_FT80
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.4689 - accuracy: 0.8440
# inception3_BS128_FT90
# 1000/1000 [==============================] - 31s 31ms/step - loss: 1.1267 - accuracy: 0.8190
# inception3_BS128_FT100
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.4880 - accuracy: 0.9220
#  * * * * * inception3_BS128_LOSS * * * * *
# 0.8707889914512634
# 0.7928164005279541
# 0.5910409688949585
# 0.8231651782989502
# 0.8447309732437134
# 0.6416346430778503
# 2.426995038986206
# 0.5388578772544861
# 0.4689027965068817
# 1.1266506910324097
# 0.4880456030368805
#  * * * * * inception3_BS128_ACCURACY * * * * *
# 0.6179999709129333
# 0.5740000009536743
# 0.6859999895095825
# 0.5789999961853027
# 0.5419999957084656
# 0.7099999785423279
# 0.6790000200271606
# 0.7820000052452087
# 0.843999981880188
# 0.8190000057220459
# 0.921999990940094
# Batch size: 256
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS256_FT0
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.7831 - accuracy: 0.6400
# inception3_BS256_FT10
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.5521 - accuracy: 0.7300
# inception3_BS256_FT20
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.7025 - accuracy: 0.6430
# inception3_BS256_FT30
# 1000/1000 [==============================] - 35s 35ms/step - loss: 1.0235 - accuracy: 0.5290
# inception3_BS256_FT40
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.7319 - accuracy: 0.5970
# inception3_BS256_FT50
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.6483 - accuracy: 0.7080
# inception3_BS256_FT60
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.6654 - accuracy: 0.7080
# inception3_BS256_FT70
# 1000/1000 [==============================] - 37s 36ms/step - loss: 0.6303 - accuracy: 0.6190
# inception3_BS256_FT80
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.5834 - accuracy: 0.8090
# inception3_BS256_FT90
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.6993 - accuracy: 0.8390
# inception3_BS256_FT100
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.5900 - accuracy: 0.7920
#  * * * * * inception3_BS256_LOSS * * * * *
# 0.7830686569213867
# 0.5521345734596252
# 0.7024908065795898
# 1.023512601852417
# 0.7319153547286987
# 0.648266613483429
# 0.6654430031776428
# 0.6302533745765686
# 0.5833963751792908
# 0.699312150478363
# 0.5899600982666016
#  * * * * * inception3_BS256_ACCURACY * * * * *
# 0.6399999856948853
# 0.7300000190734863
# 0.6430000066757202
# 0.5289999842643738
# 0.597000002861023
# 0.7080000042915344
# 0.7080000042915344
# 0.6190000176429749
# 0.8090000152587891
# 0.8389999866485596
# 0.7919999957084656
#  - - - - - TRIAL: 1  - - - - -
# Batch size: 32
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS32_FT0
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.8973 - accuracy: 0.6300
# inception3_BS32_FT10
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.5689 - accuracy: 0.7230
# inception3_BS32_FT20
# 1000/1000 [==============================] - 33s 32ms/step - loss: 0.6589 - accuracy: 0.6160
# inception3_BS32_FT30
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.6407 - accuracy: 0.6770
# inception3_BS32_FT40
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.5667 - accuracy: 0.7080
# inception3_BS32_FT50
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.4530 - accuracy: 0.7830
# inception3_BS32_FT60
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.7214 - accuracy: 0.7370
# inception3_BS32_FT70
# 1000/1000 [==============================] - 36s 35ms/step - loss: 0.4744 - accuracy: 0.8090
# inception3_BS32_FT80
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.6571 - accuracy: 0.7900
# inception3_BS32_FT90
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.4093 - accuracy: 0.8240
# inception3_BS32_FT100
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.3127 - accuracy: 0.9140
#  * * * * * inception3_BS32_LOSS * * * * *
# 0.8972859382629395
# 0.5688848495483398
# 0.658938467502594
# 0.6407204270362854
# 0.5667067766189575
# 0.4530460238456726
# 0.7214472889900208
# 0.47438183426856995
# 0.6570799350738525
# 0.40927600860595703
# 0.3126700520515442
#  * * * * * inception3_BS32_ACCURACY * * * * *
# 0.6299999952316284
# 0.7229999899864197
# 0.6159999966621399
# 0.6769999861717224
# 0.7080000042915344
# 0.7829999923706055
# 0.7369999885559082
# 0.8090000152587891
# 0.7900000214576721
# 0.8240000009536743
# 0.9139999747276306
# Batch size: 64
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS64_FT0
# 1000/1000 [==============================] - 56s 56ms/step - loss: 0.8096 - accuracy: 0.5940
# inception3_BS64_FT10
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.5672 - accuracy: 0.7180
# inception3_BS64_FT20
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.7646 - accuracy: 0.5970
# inception3_BS64_FT30
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.7411 - accuracy: 0.6260
# inception3_BS64_FT40
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.7388 - accuracy: 0.6040
# inception3_BS64_FT50
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.4754 - accuracy: 0.7970
# inception3_BS64_FT60
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.5724 - accuracy: 0.7350
# inception3_BS64_FT70
# 1000/1000 [==============================] - 37s 36ms/step - loss: 2.1862 - accuracy: 0.7300
# inception3_BS64_FT80
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.3767 - accuracy: 0.8620
# inception3_BS64_FT90
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.4525 - accuracy: 0.8350
# inception3_BS64_FT100
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.5993 - accuracy: 0.8800
#  * * * * * inception3_BS64_LOSS * * * * *
# 0.8095982670783997
# 0.5671842694282532
# 0.7645905017852783
# 0.7411436438560486
# 0.7388056516647339
# 0.47539207339286804
# 0.5723829865455627
# 2.186182975769043
# 0.3766525089740753
# 0.4524959623813629
# 0.599311351776123
#  * * * * * inception3_BS64_ACCURACY * * * * *
# 0.593999981880188
# 0.7179999947547913
# 0.597000002861023
# 0.6259999871253967
# 0.6039999723434448
# 0.796999990940094
# 0.7350000143051147
# 0.7300000190734863
# 0.8619999885559082
# 0.8349999785423279
# 0.8799999952316284
# Batch size: 128
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS128_FT0
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.8137 - accuracy: 0.6150
# inception3_BS128_FT10
# 1000/1000 [==============================] - 38s 37ms/step - loss: 0.6833 - accuracy: 0.6420
# inception3_BS128_FT20
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.9758 - accuracy: 0.5840
# inception3_BS128_FT30
# 1000/1000 [==============================] - 36s 35ms/step - loss: 1.0776 - accuracy: 0.6300
# inception3_BS128_FT40
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.4331 - accuracy: 0.8030
# inception3_BS128_FT50
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.4349 - accuracy: 0.7970
# inception3_BS128_FT60
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.6291 - accuracy: 0.7420
# inception3_BS128_FT70
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.6228 - accuracy: 0.7480
# inception3_BS128_FT80
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.6565 - accuracy: 0.8010
# inception3_BS128_FT90
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.7396 - accuracy: 0.7970
# inception3_BS128_FT100
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.5181 - accuracy: 0.9090
#  * * * * * inception3_BS128_LOSS * * * * *
# 0.8136501312255859
# 0.6832761168479919
# 0.9758124947547913
# 1.077605128288269
# 0.43310654163360596
# 0.43485474586486816
# 0.6291119456291199
# 0.6227642893791199
# 0.6565362811088562
# 0.7396407127380371
# 0.5181050896644592
#  * * * * * inception3_BS128_ACCURACY * * * * *
# 0.6150000095367432
# 0.6420000195503235
# 0.5839999914169312
# 0.6299999952316284
# 0.8029999732971191
# 0.796999990940094
# 0.7419999837875366
# 0.7480000257492065
# 0.8009999990463257
# 0.796999990940094
# 0.9089999794960022
# Batch size: 256
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS256_FT0
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.9578 - accuracy: 0.5800
# inception3_BS256_FT10
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.6783 - accuracy: 0.6910
# inception3_BS256_FT20
# 1000/1000 [==============================] - 32s 31ms/step - loss: 0.8811 - accuracy: 0.5430
# inception3_BS256_FT30
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.9600 - accuracy: 0.5980
# inception3_BS256_FT40
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.7152 - accuracy: 0.7200
# inception3_BS256_FT50
# 1000/1000 [==============================] - 32s 31ms/step - loss: 0.5506 - accuracy: 0.7570
# inception3_BS256_FT60
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.5195 - accuracy: 0.7900
# inception3_BS256_FT70
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.5258 - accuracy: 0.7800
# inception3_BS256_FT80
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.7710 - accuracy: 0.7220
# inception3_BS256_FT90
# 1000/1000 [==============================] - 24s 24ms/step - loss: 1.8907 - accuracy: 0.7250
# inception3_BS256_FT100
# 1000/1000 [==============================] - 28s 27ms/step - loss: 0.8662 - accuracy: 0.8930
#  * * * * * inception3_BS256_LOSS * * * * *
# 0.9578016996383667
# 0.678263783454895
# 0.8811070919036865
# 0.959966242313385
# 0.7151637673377991
# 0.5505923628807068
# 0.5195443630218506
# 0.5258265733718872
# 0.771013081073761
# 1.8906559944152832
# 0.8662156462669373
#  * * * * * inception3_BS256_ACCURACY * * * * *
# 0.5799999833106995
# 0.6909999847412109
# 0.5429999828338623
# 0.5979999899864197
# 0.7200000286102295
# 0.7570000290870667
# 0.7900000214576721
# 0.7799999713897705
# 0.722000002861023
# 0.7250000238418579
# 0.8930000066757202
#  - - - - - TRIAL: 2  - - - - -
# Batch size: 32
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS32_FT0
# 1000/1000 [==============================] - 29s 28ms/step - loss: 0.6448 - accuracy: 0.6970
# inception3_BS32_FT10
# 1000/1000 [==============================] - 29s 28ms/step - loss: 0.6662 - accuracy: 0.7050
# inception3_BS32_FT20
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6513 - accuracy: 0.7060
# inception3_BS32_FT30
# 1000/1000 [==============================] - 27s 27ms/step - loss: 0.6798 - accuracy: 0.6160
# inception3_BS32_FT40
# 1000/1000 [==============================] - 60s 59ms/step - loss: 0.5109 - accuracy: 0.7420
# inception3_BS32_FT50
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.5621 - accuracy: 0.6980
# inception3_BS32_FT60
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.5974 - accuracy: 0.7590
# inception3_BS32_FT70
# 1000/1000 [==============================] - 28s 28ms/step - loss: 0.4404 - accuracy: 0.8140
# inception3_BS32_FT80
# 1000/1000 [==============================] - 27s 27ms/step - loss: 1.4722 - accuracy: 0.7290
# inception3_BS32_FT90
# 1000/1000 [==============================] - 27s 27ms/step - loss: 0.6683 - accuracy: 0.7750
# inception3_BS32_FT100
# 1000/1000 [==============================] - 26s 26ms/step - loss: 1.3014 - accuracy: 0.7930
#  * * * * * inception3_BS32_LOSS * * * * *
# 0.6447721123695374
# 0.6662274599075317
# 0.6513432264328003
# 0.6798145174980164
# 0.5109154582023621
# 0.5620854496955872
# 0.5974025130271912
# 0.44037118554115295
# 1.472202181816101
# 0.6683293581008911
# 1.3014036417007446
#  * * * * * inception3_BS32_ACCURACY * * * * *
# 0.6970000267028809
# 0.7049999833106995
# 0.7059999704360962
# 0.6159999966621399
# 0.7419999837875366
# 0.6980000138282776
# 0.7590000033378601
# 0.8140000104904175
# 0.7289999723434448
# 0.7749999761581421
# 0.7929999828338623
# Batch size: 64
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS64_FT0
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6787 - accuracy: 0.6880
# inception3_BS64_FT10
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6112 - accuracy: 0.6480
# inception3_BS64_FT20
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.5921 - accuracy: 0.6880
# inception3_BS64_FT30
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.7530 - accuracy: 0.6460
# inception3_BS64_FT40
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.5867 - accuracy: 0.6920
# inception3_BS64_FT50
# 1000/1000 [==============================] - 26s 25ms/step - loss: 0.4632 - accuracy: 0.8010
# inception3_BS64_FT60
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.5453 - accuracy: 0.7070
# inception3_BS64_FT70
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.8349 - accuracy: 0.7310
# inception3_BS64_FT80
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.5407 - accuracy: 0.7930
# inception3_BS64_FT90
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.7881 - accuracy: 0.7620
# inception3_BS64_FT100
# 1000/1000 [==============================] - 26s 25ms/step - loss: 0.3168 - accuracy: 0.9220
#  * * * * * inception3_BS64_LOSS * * * * *
# 0.6787087321281433
# 0.6112368702888489
# 0.5920662879943848
# 0.7529946565628052
# 0.5866677761077881
# 0.46323686838150024
# 0.545342206954956
# 0.8349241614341736
# 0.5406684279441833
# 0.7881019115447998
# 0.3167947828769684
#  * * * * * inception3_BS64_ACCURACY * * * * *
# 0.6880000233650208
# 0.6480000019073486
# 0.6880000233650208
# 0.6460000276565552
# 0.6919999718666077
# 0.8009999990463257
# 0.7070000171661377
# 0.7310000061988831
# 0.7929999828338623
# 0.7620000243186951
# 0.921999990940094
# Batch size: 128
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS128_FT0
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.8535 - accuracy: 0.5820
# inception3_BS128_FT10
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6078 - accuracy: 0.6900
# inception3_BS128_FT20
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6085 - accuracy: 0.6970
# inception3_BS128_FT30
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6754 - accuracy: 0.6170
# inception3_BS128_FT40
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.4810 - accuracy: 0.7730
# inception3_BS128_FT50
# 1000/1000 [==============================] - 26s 25ms/step - loss: 0.6912 - accuracy: 0.5740
# inception3_BS128_FT60
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6398 - accuracy: 0.7680
# inception3_BS128_FT70
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.5148 - accuracy: 0.7830
# inception3_BS128_FT80
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.5441 - accuracy: 0.7150
# inception3_BS128_FT90
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.8206 - accuracy: 0.8210
# inception3_BS128_FT100
# 1000/1000 [==============================] - 19s 19ms/step - loss: 3.1107 - accuracy: 0.6350
#  * * * * * inception3_BS128_LOSS * * * * *
# 0.8535099029541016
# 0.6078486442565918
# 0.608519971370697
# 0.675401508808136
# 0.4810391664505005
# 0.6912482976913452
# 0.639840841293335
# 0.5147881507873535
# 0.5441019535064697
# 0.8205825090408325
# 3.110670804977417
#  * * * * * inception3_BS128_ACCURACY * * * * *
# 0.5820000171661377
# 0.6899999976158142
# 0.6970000267028809
# 0.6169999837875366
# 0.7730000019073486
# 0.5740000009536743
# 0.7680000066757202
# 0.7829999923706055
# 0.7149999737739563
# 0.8209999799728394
# 0.6349999904632568
# Batch size: 256
# Found 9980 files belonging to 2 classes.
# Using 8982 files for training.
# Found 9980 files belonging to 2 classes.
# Using 998 files for validation.
# Found 1000 files belonging to 2 classes.
# inception3_BS256_FT0
# 1000/1000 [==============================] - 18s 18ms/step - loss: 0.8242 - accuracy: 0.5890
# inception3_BS256_FT10
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.5848 - accuracy: 0.7150
# inception3_BS256_FT20
# 1000/1000 [==============================] - 18s 18ms/step - loss: 1.3142 - accuracy: 0.5730
# inception3_BS256_FT30
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.8837 - accuracy: 0.5910
# inception3_BS256_FT40
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.7523 - accuracy: 0.6040
# inception3_BS256_FT50
# 1000/1000 [==============================] - 17s 17ms/step - loss: 2.6452 - accuracy: 0.6640
# inception3_BS256_FT60
# 1000/1000 [==============================] - 20s 20ms/step - loss: 1.2325 - accuracy: 0.5600
# inception3_BS256_FT70
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.8816 - accuracy: 0.6190
# inception3_BS256_FT80
# 1000/1000 [==============================] - 18s 17ms/step - loss: 0.8189 - accuracy: 0.7710
# inception3_BS256_FT90
# 1000/1000 [==============================] - 17s 17ms/step - loss: 2.1612 - accuracy: 0.7670
# inception3_BS256_FT100
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6976 - accuracy: 0.8810
#  * * * * * inception3_BS256_LOSS * * * * *
# 0.8242133259773254
# 0.5847650766372681
# 1.3142033815383911
# 0.8837091326713562
# 0.7523211240768433
# 2.6452126502990723
# 1.2324882745742798
# 0.8815656304359436
# 0.8189402222633362
# 2.1611545085906982
# 0.69758540391922
#  * * * * * inception3_BS256_ACCURACY * * * * *
# 0.5889999866485596
# 0.7149999737739563
# 0.5730000138282776
# 0.5910000205039978
# 0.6039999723434448
# 0.6639999747276306
# 0.5600000023841858
# 0.6190000176429749
# 0.7710000276565552
# 0.7670000195503235
# 0.8809999823570251
